# %% [markdown]
# # Customer Churn Prediction using Explainable Machine Learning\nCSC-44112 Assessment Part 2\n

# %% [markdown]
# ## Use the Python script for the complete reproducible pipeline\n

# %%
# %run churn_prediction_project.py\n
